# %% [markdown]
# <a href="https://colab.research.google.com/github/Svein-Tore/colab/blob/main/Lambda_tuning_interaktiv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interaktiv λ‑tuning for FOPDT‑prosess (PI‑regulator)
#
# Denne notatboken lar deg utforske **Lambda-/Skogestad‑metoden** ved å justere prosessparametrene **K**, **T**, **L** og ønsket lukket sløyfe‑tidskonstant **λ** med sliders.
#
# **Formler (fra undervisningsopplegget):**
# - $K_p = \dfrac{T}{K(\lambda + L)}$
# - $T_i = \min\big(T,\;4(\lambda + L)\big)$
#
# Kjør cellene fra toppen og bruk sliderne til å se hvordan **PV** og **pådrag u** endrer seg.

# %%
# ============================================================
#  FOPDT + PI (λ-tuning)
#  Intern: 0–1
#  Visning: %
# ============================================================

# --- Setup (Colab / Jupyter) ---
import sys
try:
    import ipywidgets
except ImportError:
    # !pip install -q ipywidgets
    import ipywidgets

try:
    from google.colab import output
    output.enable_custom_widget_manager()
except Exception:
    pass

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from ipywidgets import FloatSlider, HBox, VBox, Output

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 11


# ------------------------------------------------------------
#  Simulering
# ------------------------------------------------------------
def simulate_fopdt_pi(
    K=2.904, T=125.4, L=5.2, lam=62.7,
    SP_percent=100.0,
    dt=0.1, T_end=300.0,
    u_min_pct=0.0, u_max_pct=100.0
):
    # Lambda / Skogestad tuning
    Kp = T / (K * (lam + L))
    Ti = min(T, 4.0 * (lam + L))

    time = np.arange(0.0, T_end + dt, dt)

    # Normaliserte signaler
    sp = np.full_like(time, SP_percent / 100.0)
    y  = np.zeros_like(time)
    u  = np.zeros_like(time)

    e_int = 0.0

    delay_steps = int(np.round(L / dt))
    u_buf = np.zeros(delay_steps + 1)

    for k in range(1, len(time)):
        # PI-regulator
        e = sp[k] - y[k - 1]
        e_int += e * dt

        u_raw = Kp * (e + e_int / Ti)

        # Klipp i prosent (HMI)
        u_pct = np.clip(u_raw * 100.0, u_min_pct, u_max_pct)
        u[k] = u_pct / 100.0

        # Dødtid
        if delay_steps > 0:
            u_buf = np.roll(u_buf, 1)
            u_buf[0] = u[k]
            u_delay = u_buf[-1]
        else:
            u_delay = u[k]

        # FOPDT-prosess
        dy = (-y[k - 1] + K * u_delay) / T
        y[k] = y[k - 1] + dy * dt

    return time, sp * 100.0, y * 100.0, u * 100.0, Kp, Ti


# ------------------------------------------------------------
#  Standardverdier
# ------------------------------------------------------------
K0, T0, L0 = 2.904, 125.4, 5.2
lam0 = T0 / 2


# ------------------------------------------------------------
#  Sliders (KUN keyword-argumenter)
# ------------------------------------------------------------
K_sl = FloatSlider(
    value=K0, min=0.1, max=10.0, step=0.01, description='K'
)

T_sl = FloatSlider(
    value=T0, min=5.0, max=500.0, step=0.1, description='T [s]'
)

L_sl = FloatSlider(
    value=L0, min=0.0, max=60.0, step=0.1, description='L [s]'
)

lam_sl = FloatSlider(
    value=lam0, min=0.1, max=400.0, step=0.1, description='λ [s]'
)

sp_sl = FloatSlider(
    value=100.0, min=0.0, max=100.0, step=1.0, description='SP [%]'
)

dt_sl = FloatSlider(
    value=0.1, min=0.02, max=0.5, step=0.01, description='Δt [s]'
)

Tend_sl = FloatSlider(
    value=300.0, min=30.0, max=1200.0, step=10.0, description='T_end [s]'
)

u_sl = FloatSlider(
    value=100.0, min=0.0, max=100.0, step=5.0, description='u_max [%]'
)

out_fig = Output()


# ------------------------------------------------------------
#  Plot
# ------------------------------------------------------------
def update_plot(change=None):
    with out_fig:
        out_fig.clear_output(wait=True)

        time, sp, y, u, Kp, Ti = simulate_fopdt_pi(
            K_sl.value, T_sl.value, L_sl.value,
            lam_sl.value,
            sp_sl.value,
            dt_sl.value,
            Tend_sl.value,
            0.0, u_sl.value
        )

        fig, (ax1, ax2) = plt.subplots(
            2, 1, figsize=(7.2, 6),
            sharex=True,
            gridspec_kw={'height_ratios': [2, 1]}
        )

        ax1.plot(time, sp, 'k--', lw=1.2, label='SP [%]')
        ax1.plot(time, y, lw=2.0, label='PV [%]')
        ax1.set_ylabel('PV / SP [%]')
        ax1.legend(loc='lower right')
        ax1.grid(True, alpha=0.3)

        ax1.set_title(
            f'FOPDT + PI (λ-tuning) | '
            f'Kp={Kp:.3f}, Ti={Ti:.1f}s'
        )

        ax2.plot(time, u, lw=1.6)
        ax2.set_ylabel('u [%]')
        ax2.set_xlabel('Tid [s]')
        ax2.grid(True, alpha=0.3)

        plt.show()


# ------------------------------------------------------------
#  Koble sliders
# ------------------------------------------------------------
for w in (K_sl, T_sl, L_sl, lam_sl, sp_sl, dt_sl, Tend_sl, u_sl):
    w.observe(update_plot, names='value')

update_plot()

display(
    VBox([
        HBox([K_sl, T_sl]),
        HBox([L_sl, lam_sl]),
        HBox([sp_sl]),
        HBox([dt_sl, Tend_sl, u_sl]),
        out_fig
    ])
)
